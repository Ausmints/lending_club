# %%
import numpy as np
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from AUS_Functions import *
import re

# %%
sns.set()
colors = {
    "blue": "#4C72B0",
    "orange": "#DD8452",
    "green": "#55A868",
    "red": "#C44E52",
    "grey": "#8C8C8C",
}

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv('rejected_2007_to_2018Q4.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27648741 entries, 0 to 27648740
# Data columns (total 9 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Amount Requested      float64
#  1   Application Date      object
#  2   Loan Title            object
#  3   Risk_Score            float64
#  4   Debt-To-Income Ratio  object
#  5   Zip Code              object
#  6   State                 object
#  7   Employment Length     object
#  8   Policy Code           float64
# dtypes: float64(3), object(6)
# memory usage: 1.9+ GB

# %%
df.isnull().sum()
# Out:
# Amount Requested               0
# Application Date               0
# Loan Title                  1303
# Risk_Score              18497630
# Debt-To-Income Ratio           0
# Zip Code                     293
# State                         22
# Employment Length         951355
# Policy Code                  918
# dtype: int64

# %%
df.columns = df.columns.str.replace(" |-", "_", regex=True).str.lower()

df_sample = df.sample(frac = 0.1)
df = df.dropna(axis=0)
df = df.sample(frac = 0.25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2248049 entries, 26281062 to 12756082
# Data columns (total 9 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   amount_requested      float64
#  1   application_date      object
#  2   loan_title            object
#  3   risk_score            float64
#  4   debt_to_income_ratio  object
#  5   zip_code              object
#  6   state                 object
#  7   employment_length     object
#  8   policy_code           float64
# dtypes: float64(3), object(6)
# memory usage: 171.5+ MB

# %%
df["dropna"] = 1
df_sample["dropna"] = 0
df = pd.concat([df, df_sample])
df = df.reset_index(drop=True)

del(df_sample)

# %%
df.head()
# Out:
#           amount_requested application_date          loan_title  risk_score  \
# 26281062            2000.0       2016-10-04  Debt consolidation       594.0
# 142890             25000.0       2010-07-31   Eliminate CC Debt       691.0
# 7818300            35000.0       2014-01-21  debt_consolidation       745.0
# 1310153            13000.0       2016-05-16         credit_card       703.0
# 27167684           18000.0       2016-11-30  Debt consolidation       704.0
#
#          debt_to_income_ratio zip_code state employment_length  policy_code
# 26281062               14.72%    727xx    AR          < 1 year          0.0
# 142890                  5.27%    921xx    CA         10+ years          0.0
# 7818300                  232%    312xx    GA          < 1 year          0.0
# 1310153                55.18%    928xx    CA          < 1 year          0.0
# 27167684               46.17%    923xx    CA          < 1 year          0.0

# %%
df["application_date"] = pd.to_datetime(df["application_date"])
df["month"] = df["application_date"].dt.month

# %%
plt.figure(figsize=(20, 10))
ax = sns.kdeplot(
    data=df,
    x="application_date",
    hue="dropna",
    palette=[colors["grey"], colors["orange"]],
    common_norm=False
)
plt.legend(labels=["Dropped na", "With na"], title="")
ax.set(xlabel="x", ylabel="y")
ax.set_title("Title")

plt.show()

# %%
df_month = df.loc[:, ["month", "dropna", "policy_code"]]
df_month.index.name = "id"

draw_comparison_barplot(df_month, "dropna", "month", [1], ["Title", "x", "y", "with na", "dropped na"], mode="proportion")

# %%
df = pd.read_csv('rejected_2007_to_2018Q4.csv')
df.columns = df.columns.str.replace(" |-", "_", regex=True).str.lower()
df = df.sample(frac = 0.1)

# %%
df2 = pd.read_csv('accepted_2007_to_2018Q4.csv')
# Out:
# <ipython-input-33-991a2584021c>:1: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('accepted_2007_to_2018Q4.csv')

# %%
df["accepted"] = 0
df2["accepted"] = 1

# %%
df = df.loc[:, ["application_date", "accepted"]]

# %%
df2 = df2.loc[:, ["issue_d", "accepted"]]

# %%
df2 = df2.rename(columns={"issue_d":"application_date"})

# %%
df = df.to_frame()
df2 = df2.to_frame()
df["accepted"] = 0
df2["accepted"] = 1

# %%
df = pd.concat([df, df2])
df = df.reset_index(drop=True)

# %%
df
# Out:
#         application_date  accepted
# 0             2018-11-18         0
# 1             2017-08-01         0
# 2             2018-11-09         0
# 3             2018-07-16         0
# 4             2018-03-24         0
# ...                  ...       ...
# 5025570       2016-10-01         1
# 5025571       2016-10-01         1
# 5025572       2016-10-01         1
# 5025573              NaT         1
# 5025574              NaT         1
#
# [5025575 rows x 2 columns]

# %%
df["application_date"] = pd.to_datetime(df["application_date"])

# %%
df["month"] = df["application_date"].dt.month

# %%
pd.to_datetime([str(2007 + x) for x in range(13)])
# Out:
# DatetimeIndex(['2007-01-01', '2008-01-01', '2009-01-01', '2010-01-01',
#                '2011-01-01', '2012-01-01', '2013-01-01', '2014-01-01',
#                '2015-01-01', '2016-01-01', '2017-01-01', '2018-01-01',
#                '2019-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
plt.figure(figsize=(20, 10))
ax = sns.kdeplot(
    data=df,
    x="application_date",
    hue="accepted",
    palette=[colors["grey"], colors["orange"]],
    common_norm=False
)
plt.legend(labels=["Accepted", "Rejected"], title="")
ax.set(xlabel="x", ylabel="y")
ax.set_xticks(pd.to_datetime([str(2007 + x) for x in range(13)]))
ax.set_xticklabels([2007 + x for x in range(13)])
ax.set_title("Title")

plt.show()

# %%
df.index.name = "id"
draw_comparison_barplot(df, "accepted", "month", [3, 9], ["Title", "x", "y", "Rejected", "Accepted"], mode="proportion")
# Out:
# C:\Users\Ausmints\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Ausmints\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Ausmints\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Ausmints\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)

# %%
def df2_to_df(df2):
    df2 = df2.loc[:, ["loan_amnt", "title", "fico_range_low", "fico_range_high", "dti", "zip_code", "addr_state", "emp_length", "loan_status"]]
    df2["risk_score"] = (df2["fico_range_low"] + df2["fico_range_high"])/2
    df2["accepted"] = 1
    df2.loc[df2["loan_status"] == "Charged Off","accepted"] = 2
    df2 = df2.drop(["fico_range_low", "fico_range_high", "loan_status"], axis=1)
    
    df2_name_dict = {
        "loan_amnt":"amount_requested",
        "title":"loan_title",
        "dti":"debt_to_income_ratio",
        "addr_state":"state",
        "emp_length":"employment_length"
    }
    df2 = df2.rename(columns=df2_name_dict)
    return df2

# %%
def clean_data(df):
    df["employment_length"] = df["employment_length"].replace({"10+ years":"15", "< 1 year":"0"})
    df["employment_length"] = df["employment_length"].str.extract(r"([0-9]+)").astype("float")
    df = df.rename(columns={"employment_length" : "employment_length_years"})
    df["debt_to_income_ratio"] = df["debt_to_income_ratio"].replace("%", "", regex=True).astype(float)
    df["amount_requested"] = df["amount_requested"].astype(int)
    
    df.loc[:, "loan_title"] = df["loan_title"].str.lower().replace("[^a-zA-Z0-9]", " ", regex=True)

    fcols = df.select_dtypes('float').columns
    icols = df.select_dtypes('integer').columns
    df[fcols] = df[fcols].apply(pd.to_numeric, downcast='float')
    df[icols] = df[icols].apply(pd.to_numeric, downcast='integer')
    
    df = df.drop(df[df["zip_code"].isnull()].index.tolist(), axis=0)
    df["bin"] = df["zip_code"].str.strip("x") + df["state"]
    df = df.merge(bin_coord_means.reset_index(), on="bin", how="left")
    df = df.merge(state_coord_means.reset_index(), on="state", how="left")
    df["latitude"] = df["latitude"].fillna(df["state_latitude"])
    df["longitude"] = df["longitude"].fillna(df["state_longitude"])
    df.drop(["zip_code", "bin"], axis=1, inplace=True)
    
    return df

# %%
def lower_data_size_1st_model(df):
    df["application_date"] = pd.to_datetime(df["application_date"])
    
    df["employment_length"] = df["employment_length"].replace({"10+ years":"15", "< 1 year":"0"})
    df["employment_length"] = df["employment_length"].str.extract(r"([0-9]+)").astype("int")
    df.rename(columns={"employment_length" : "employment_length_years"})
    
    df["debt_to_income_ratio"] = df["debt_to_income_ratio"].replace("%", "", regex=True).astype(float)
    
    int_list = object_to_int_list + ["amount_requested", "risk_score", "policy_code", "employment_length_years"]
    df["debt_to_income_ratio"] = df["debt_to_income_ratio"].apply(pd.to_numeric, downcast='float')
    df[int_list] = df[int_list].apply(pd.to_numeric, downcast='integer')
    
    return df

# %%
df = pd.read_csv('rejected_2007_to_2018Q4.csv')
df = df.dropna(axis=0)
df = df.sample(frac = 0.25)
df.columns = df.columns.str.replace(" |-", "_", regex=True).str.lower()

df["accepted"] = 0
df = df.drop(["policy_code", "application_date"], axis=1)

# %%
df2 = pd.read_csv('accepted_2007_to_2018Q4.csv')
df2 = df2_to_df(df2)
# Out:
# C:\Users\Ausmints\AppData\Local\Temp\ipykernel_107932\2059039889.py:1: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('accepted_2007_to_2018Q4.csv')

# %%
df2.isnull().sum()
# Out:
# amount_requested            33
# loan_title               23358
# debt_to_income_ratio      1744
# zip_code                    34
# state                       33
# employment_length       146940
# risk_score                  33
# accepted                     0
# dtype: int64

# %%
df2 = df2.drop(df2[df2["amount_requested"].isnull()].index, axis=0)

df = pd.concat([df, df2])
df = df.reset_index(drop=True)

del(df2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4508717 entries, 0 to 4508716
# Data columns (total 8 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   amount_requested      float64
#  1   loan_title            object
#  2   risk_score            float64
#  3   debt_to_income_ratio  object
#  4   zip_code              object
#  5   state                 object
#  6   employment_length     object
#  7   accepted              int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 275.2+ MB

# %%
df.head()
# Out:
#    amount_requested               loan_title  risk_score debt_to_income_ratio  \
# 0            2000.0       Debt consolidation       549.0               31.52%
# 1            1000.0                    other       577.0                   0%
# 2            5400.0  Credit card refinancing       666.0               30.35%
# 3           15000.0              Home buying       596.0                7.79%
# 4           25000.0       Debt consolidation       599.0               38.55%
#
#   zip_code state employment_length  accepted
# 0    165xx    PA          < 1 year         0
# 1    042xx    ME           5 years         0
# 2    730xx    OK          < 1 year         0
# 3    330xx    FL          < 1 year         0
# 4    917xx    CA          < 1 year         0

# %%
zip_df = pd.read_csv("US_zip_codes_coordinates.txt", sep="\t", header=None)
zip_df = zip_df.drop([0, 2, 3, 5, 6, 7, 8, 11], axis=1)
zip_df.columns = ["zip_code", "state", "latitude", "longitude"]
zip_df = zip_df.dropna(axis=0)

zip_df["bin"] = np.floor(zip_df["zip_code"] / 100).astype(int).astype(str).str.zfill(3) + zip_df["state"]
state_coord_means = zip_df.groupby("state")[["latitude", "longitude"]].mean()
state_coord_means = state_coord_means.rename(columns={"latitude":"state_latitude", "longitude":"state_longitude"})
bin_coord_means = zip_df.groupby("bin")[["latitude", "longitude"]].mean()

zip_df.head()
# Out:
#    zip_code state  latitude  longitude    bin
# 0     99553    AK   54.1430  -165.7854  995AK
# 1     99571    AK   55.1858  -162.7211  995AK
# 2     99583    AK   54.8542  -163.4113  995AK
# 3     99612    AK   55.0628  -162.3056  996AK
# 4     99661    AK   55.3192  -160.4914  996AK

# %%
df = clean_data(df)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4508716 entries, 0 to 4508715
# Data columns (total 11 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   amount_requested         int32
#  1   loan_title               object
#  2   risk_score               float32
#  3   debt_to_income_ratio     float32
#  4   state                    object
#  5   employment_length_years  float32
#  6   accepted                 int8
#  7   latitude                 float64
#  8   longitude                float64
#  9   state_latitude           float64
#  10  state_longitude          float64
# dtypes: float32(3), float64(4), int32(1), int8(1), object(2)
# memory usage: 313.9+ MB

# %%
df.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#       amount_requested     risk_score debt_to_income_ratio  \
# count    4508716.00000  4508716.00000        4507005.00000
# mean       13839.14014      664.06189            101.00349
# std        10164.99282       76.94199          23920.55469
# min          150.00000        0.00000             -1.00000
# 25%         5175.00000      636.00000             10.89000
# 50%        10500.00000      675.00000             18.74000
# 75%        20000.00000      702.00000             28.44000
# max      1400000.00000      990.00000       50000032.00000
#
#       employment_length_years       accepted       latitude      longitude  \
# count           4361809.00000  4508716.00000  4508716.00000  4508716.00000
# mean                  4.06381        0.56096       37.17007      -91.86516
# std                   5.67485        0.60449        5.23467       16.89231
# min                   0.00000        0.00000       20.81159     -157.04715
# 25%                   0.00000        0.00000       33.62983     -100.90443
# 50%                   0.00000        1.00000       37.99624      -86.16212
# 75%                   6.00000        1.00000       40.84899      -78.88832
# max                  15.00000        2.00000       65.71959      -68.01060
#
#       state_latitude state_longitude
# count  4508716.00000   4508716.00000
# mean        37.35620       -92.15209
# std          5.04501        16.80369
# min         20.98386      -154.97500
# 25%         33.60767       -97.99790
# 50%         37.71436       -86.26746
# 75%         40.61983       -78.23115
# max         61.46674       -69.43048

# %%
df["accepted"].value_counts()
# Out:
# 0    2248049
# 1    1992108
# 2     268559
# Name: accepted, dtype: int64

# %%
plt.figure(figsize=(20, 10))
ax = sns.kdeplot(
    data=df[df["amount_requested"]<50000],
    x="amount_requested",
    hue="accepted",
    palette=[colors["grey"], colors["orange"], colors["green"]],
    common_norm=False
)
plt.legend(labels=["Charged Off", "Accepted", "Rejected"], title="")
ax.set(xlabel="x", ylabel="y")
ax.set_title("Title")

plt.show()

# %%
plt.figure(figsize=(20, 10))
ax = sns.kdeplot(
    data=df,
    x="risk_score",
    hue="accepted",
    palette=[colors["grey"], colors["orange"], colors["green"]],
    common_norm=False
)
plt.legend(labels=["Charged Off", "Accepted", "Rejected"], title="")
ax.set(xlabel="x", ylabel="y")
ax.set_title("Title")

plt.show()

# %%
plt.figure(figsize=(20, 10))
ax = sns.kdeplot(
    data=df[df["debt_to_income_ratio"]<200],
    x="debt_to_income_ratio",
    hue="accepted",
    palette=[colors["grey"], colors["orange"], colors["green"]],
    common_norm=False
)
plt.legend(labels=["Charged Off", "Accepted", "Rejected"], title="")
ax.set(xlabel="x", ylabel="y")
ax.set_title("Title")

plt.show()

# %%
plt.figure(figsize=(20, 10))
ax = sns.violinplot(
    data=df,
    y="employment_length",
    x="accepted",
    palette=[colors["grey"], colors["orange"], colors["green"]]
)
plt.legend(labels=["Charged Off", "Accepted", "Rejected"], title="")
ax.set(xlabel="x", ylabel="y")
ax.set_title("Title")

plt.show()

# %%
df
# Out:
#          amount_requested          loan_title  risk_score  \
# 0                   12500  debt consolidation       705.0
# 1                   40000  debt consolidation       764.0
# 2                   20000  debt consolidation       659.0
# 3                    1000               other       624.0
# 4                    1000               other       774.0
# ...                   ...                 ...         ...
# 4508712             24000    home improvement       667.0
# 4508713             24000  debt consolidation       697.0
# 4508714             40000                 NaN       707.0
# 4508715             24000  debt consolidation       662.0
# 4508716             14000                 NaN       662.0
#
#          debt_to_income_ratio zip_code state  employment_length_years  \
# 0                   60.669998    933xx    CA                      0.0
# 1                   30.540001    770xx    TX                      0.0
# 2                   39.090000    890xx    NV                      0.0
# 3                   18.790001    953xx    CA                      0.0
# 4                   19.730000    967xx    HI                      0.0
# ...                       ...      ...   ...                      ...
# 4508712             19.610001    356xx    AL                      7.0
# 4508713             34.939999    840xx    UT                     15.0
# 4508714             12.750000    907xx    CA                      9.0
# 4508715             18.299999    334xx    FL                      6.0
# 4508716             23.360001    770xx    TX                     15.0
#
#          accepted
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 4508712         1
# 4508713         1
# 4508714         1
# 4508715         2
# 4508716         1
#
# [4508717 rows x 8 columns]

# %%
word_df = pd.Series([y for x in df["loan_title"].dropna().values.flatten() for y in x.split()]).value_counts().to_frame("total")
word_df["total"] = (word_df["total"]/word_df["total"].sum()).round(3)
for index, value in enumerate(["rejected", "accepted", "charged_off"]):
    word_df[value] = pd.Series([y for x in df.loc[df["accepted"] == index, "loan_title"].dropna().values.flatten() for y in x.split()]).value_counts()
    word_df[value] = (word_df[value]/word_df[value].sum()).round(3)

# %%
word_df.head(10)
# Out:
#                total  rejected  accepted  charged_off
# debt            0.25      0.25      0.24         0.27
# consolidation   0.25      0.25      0.24         0.27
# credit          0.09      0.07      0.10         0.08
# card            0.09      0.07      0.10         0.08
# refinancing     0.07      0.04      0.10         0.08
# other           0.05      0.08      0.03         0.03
# home            0.03      0.03      0.03         0.03
# improvement     0.03      0.02      0.03         0.03
# car             0.02      0.03      0.00         0.00
# purchase        0.01      0.02      0.01         0.01

# %%
word_df = word_df.loc[word_df["total"] > 0.01, ["rejected", "accepted"]]
word_df = word_df.unstack().reset_index().rename(columns={"level_0":"accepted", "level_1":"word", 0:"count"})
word_df.index.name = "id"

draw_comparison_barplot(word_df, "accepted", "word", ["other", "refinancing"], ["Title", "x", "y", "Accepted", "Rejected"], mode="")

# %%
df
# Out:
#          amount_requested          loan_title  risk_score  \
# 0                   12500  debt consolidation       705.0
# 1                   40000  debt consolidation       764.0
# 2                   20000  debt consolidation       659.0
# 3                    1000               other       624.0
# 4                    1000               other       774.0
# ...                   ...                 ...         ...
# 4508711             24000    home improvement       667.0
# 4508712             24000  debt consolidation       697.0
# 4508713             40000                 NaN       707.0
# 4508714             24000  debt consolidation       662.0
# 4508715             14000                 NaN       662.0
#
#          debt_to_income_ratio state  employment_length_years  accepted  \
# 0                   60.669998    CA                      0.0         0
# 1                   30.540001    TX                      0.0         0
# 2                   39.090000    NV                      0.0         0
# 3                   18.790001    CA                      0.0         0
# 4                   19.730000    HI                      0.0         0
# ...                       ...   ...                      ...       ...
# 4508711             19.610001    AL                      7.0         1
# 4508712             34.939999    UT                     15.0         1
# 4508713             12.750000    CA                      9.0         1
# 4508714             18.299999    FL                      6.0         2
# 4508715             23.360001    TX                     15.0         1
#
#           latitude   longitude  state_latitude  state_longitude
# 0        35.334818 -118.985686       36.170875      -119.792944
# 1        29.775927  -95.414295       31.274343       -97.997900
# 2        36.483187 -115.319346       37.835033      -116.651705
# 3        37.632906 -120.692714       36.170875      -119.792944
# 4        20.811593 -157.047147       20.983855      -154.974999
# ...            ...         ...             ...              ...
# 4508711  34.702170  -87.298511       32.887726       -86.814216
# 4508712  40.630686 -111.421653       39.908213      -111.830886
# 4508713  33.798261 -118.186126       36.170875      -119.792944
# 4508714  26.606844  -80.175235       28.127902       -81.955584
# 4508715  29.775927  -95.414295       31.274343       -97.997900
#
# [4508716 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4508716 entries, 0 to 4508715
# Data columns (total 11 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   amount_requested         int32
#  1   loan_title               object
#  2   risk_score               float32
#  3   debt_to_income_ratio     float32
#  4   state                    object
#  5   employment_length_years  float32
#  6   accepted                 int8
#  7   latitude                 float64
#  8   longitude                float64
#  9   state_latitude           float64
#  10  state_longitude          float64
# dtypes: float32(3), float64(4), int32(1), int8(1), object(2)
# memory usage: 313.9+ MB

# %%
plt.figure(figsize=(20, 10))
ax = sns.kdeplot(
    data=df[df["debt_to_income_ratio"]<200],
    x="latitude",
    hue="accepted",
    palette=[colors["grey"], colors["orange"], colors["green"]],
    common_norm=False
)
plt.legend(labels=["Charged Off", "Accepted", "Rejected"], title="")
ax.set(xlabel="x", ylabel="y")
ax.set_title("Title")

plt.show()

# %%
plt.figure(figsize=(20, 10))
ax = sns.kdeplot(
    data=df[df["debt_to_income_ratio"]<200],
    x="longitude",
    hue="accepted",
    palette=[colors["grey"], colors["orange"], colors["green"]],
    common_norm=False
)
plt.legend(labels=["Charged Off", "Accepted", "Rejected"], title="")
ax.set(xlabel="x", ylabel="y")
ax.set_title("Title")

plt.show()

# %%
states = geopandas.read_file("maps/tl_2012_us_state.shp")

# %%
states.head()
# Out:
#    OBJECTID REGION DIVISION STATEFP   STATENS GEOID STUSPS        NAME LSAD  \
# 0         1      4        9      15  01779782    15     HI      Hawaii   00
# 1         2      3        7      05  00068085    05     AR    Arkansas   00
# 2         3      4        8      35  00897535    35     NM  New Mexico   00
# 3         4      4        8      30  00767982    30     MT     Montana   00
# 4         5      1        2      36  01779796    36     NY    New York   00
#
#    MTFCC FUNCSTAT         ALAND        AWATER     INTPTLAT      INTPTLON  \
# 0  G4000        A  1.663425e+10  1.167874e+10  +19.8097670  -155.5061027
# 1  G4000        A  1.347726e+11  2.959210e+09  +34.8955256  -092.4446262
# 2  G4000        A  3.141611e+11  7.564385e+08  +34.4346843  -106.1316181
# 3  G4000        A  3.769636e+11  3.868565e+09  +47.0511771  -109.6348174
# 4  G4000        A  1.220579e+11  1.923885e+10  +42.9133974  -075.5962723
#
#      Shape_Leng    Shape_Area  \
# 0  2.419034e+06  3.268482e+10
# 1  2.656648e+06  2.053261e+11
# 2  2.900368e+06  4.643927e+11
# 3  4.607246e+06  8.201836e+11
# 4  3.212630e+06  2.637702e+11
#
#                                             geometry
# 0  MULTIPOLYGON (((-17361760.204 2164544.588, -17...
# 1  POLYGON ((-10515267.713 4101325.818, -10515269...
# 2  POLYGON ((-12138963.727 4106855.170, -12138964...
# 3  POLYGON ((-12727480.235 5886876.586, -12727567...
# 4  MULTIPOLYGON (((-8866092.533 5160809.769, -886...

# %%
states
# Out:
#     OBJECTID REGION DIVISION STATEFP   STATENS GEOID STUSPS  \
# 0          1      4        9      15  01779782    15     HI
# 1          2      3        7      05  00068085    05     AR
# 2          3      4        8      35  00897535    35     NM
# 3          4      4        8      30  00767982    30     MT
# 4          5      1        2      36  01779796    36     NY
# 5          6      2        4      38  01779797    38     ND
# 6          7      2        4      46  01785534    46     SD
# 7          8      4        8      49  01455989    49     UT
# 8          9      4        9      41  01155107    41     OR
# 9         10      4        9      53  01779804    53     WA
# 10        11      9        0      60  01802701    60     AS
# 11        12      4        8      16  01779783    16     ID
# 12        13      9        0      69  01779809    69     MP
# 13        14      9        0      72  01779808    72     PR
# 14        15      3        7      40  01102857    40     OK
# 15        16      1        2      34  01779795    34     NJ
# 16        17      1        1      44  01219835    44     RI
# 17        18      3        7      22  01629543    22     LA
# 18        19      1        1      09  01779780    09     CT
# 19        20      9        0      78  01802710    78     VI
# 20        21      3        5      54  01779805    54     WV
# 21        22      2        3      39  01085497    39     OH
# 22        23      3        6      21  01779786    21     KY
# 23        24      3        5      13  01705317    13     GA
# 24        25      3        6      28  01779790    28     MS
# 25        26      1        1      25  00606926    25     MA
# 26        27      3        5      10  01779781    10     DE
# 27        28      1        1      50  01779802    50     VT
# 28        29      1        2      42  01779798    42     PA
# 29        30      3        5      24  01714934    24     MD
# 30        31      3        6      47  01325873    47     TN
# 31        32      3        6      01  01779775    01     AL
# 32        33      3        5      51  01779803    51     VA
# 33        34      2        4      29  01779791    29     MO
# 34        35      1        1      33  01779794    33     NH
# 35        36      1        1      23  01779787    23     ME
# 36        37      3        5      45  01779799    45     SC
# 37        38      2        4      19  01779785    19     IA
# 38        39      3        5      37  01027616    37     NC
# 39        40      2        4      20  00481813    20     KS
# 40        41      2        4      31  01779792    31     NE
# 41        42      4        8      56  01779807    56     WY
# 42        43      4        8      08  01779779    08     CO
# 43        44      2        4      27  00662849    27     MN
# 44        45      2        3      55  01779806    55     WI
# 45        46      2        3      26  01779789    26     MI
# 46        47      2        3      18  00448508    18     IN
# 47        48      4        9      02  01785533    02     AK
# 48        49      3        7      48  01779801    48     TX
# 49        50      3        5      12  00294478    12     FL
# 50        51      3        5      11  01702382    11     DC
# 51        52      2        3      17  01779784    17     IL
# 52        53      9        0      66  01802705    66     GU
# 53        54      4        8      04  01779777    04     AZ
# 54        55      4        8      32  01779793    32     NV
# 55        56      4        9      06  01779778    06     CA
#
#                                             NAME LSAD  MTFCC FUNCSTAT  \
# 0                                         Hawaii   00  G4000        A
# 1                                       Arkansas   00  G4000        A
# 2                                     New Mexico   00  G4000        A
# 3                                        Montana   00  G4000        A
# 4                                       New York   00  G4000        A
# 5                                   North Dakota   00  G4000        A
# 6                                   South Dakota   00  G4000        A
# 7                                           Utah   00  G4000        A
# 8                                         Oregon   00  G4000        A
# 9                                     Washington   00  G4000        A
# 10                                American Samoa   00  G4000        A
# 11                                         Idaho   00  G4000        A
# 12  Commonwealth of the Northern Mariana Islands   00  G4000        A
# 13                                   Puerto Rico   00  G4000        A
# 14                                      Oklahoma   00  G4000        A
# 15                                    New Jersey   00  G4000        A
# 16                                  Rhode Island   00  G4000        A
# 17                                     Louisiana   00  G4000        A
# 18                                   Connecticut   00  G4000        A
# 19                  United States Virgin Islands   00  G4000        A
# 20                                 West Virginia   00  G4000        A
# 21                                          Ohio   00  G4000        A
# 22                                      Kentucky   00  G4000        A
# 23                                       Georgia   00  G4000        A
# 24                                   Mississippi   00  G4000        A
# 25                                 Massachusetts   00  G4000        A
# 26                                      Delaware   00  G4000        A
# 27                                       Vermont   00  G4000        A
# 28                                  Pennsylvania   00  G4000        A
# 29                                      Maryland   00  G4000        A
# 30                                     Tennessee   00  G4000        A
# 31                                       Alabama   00  G4000        A
# 32                                      Virginia   00  G4000        A
# 33                                      Missouri   00  G4000        A
# 34                                 New Hampshire   00  G4000        A
# 35                                         Maine   00  G4000        A
# 36                                South Carolina   00  G4000        A
# 37                                          Iowa   00  G4000        A
# 38                                North Carolina   00  G4000        A
# 39                                        Kansas   00  G4000        A
# 40                                      Nebraska   00  G4000        A
# 41                                       Wyoming   00  G4000        A
# 42                                      Colorado   00  G4000        A
# 43                                     Minnesota   00  G4000        A
# 44                                     Wisconsin   00  G4000        A
# 45                                      Michigan   00  G4000        A
# 46                                       Indiana   00  G4000        A
# 47                                        Alaska   00  G4000        A
# 48                                         Texas   00  G4000        A
# 49                                       Florida   00  G4000        A
# 50                          District of Columbia   00  G4000        A
# 51                                      Illinois   00  G4000        A
# 52                                          Guam   00  G4000        A
# 53                                       Arizona   00  G4000        A
# 54                                        Nevada   00  G4000        A
# 55                                    California   00  G4000        A
#
#            ALAND        AWATER     INTPTLAT      INTPTLON    Shape_Leng  \
# 0   1.663425e+10  1.167874e+10  +19.8097670  -155.5061027  2.419034e+06
# 1   1.347726e+11  2.959210e+09  +34.8955256  -092.4446262  2.656648e+06
# 2   3.141611e+11  7.564385e+08  +34.4346843  -106.1316181  2.900368e+06
# 3   3.769636e+11  3.868565e+09  +47.0511771  -109.6348174  4.607246e+06
# 4   1.220579e+11  1.923885e+10  +42.9133974  -075.5962723  3.212630e+06
# 5   1.787088e+11  4.398957e+09  +47.4421698  -100.4608163  3.124857e+06
# 6   1.963489e+11  3.379915e+09  +44.4467957  -100.2381762  2.962591e+06
# 7   2.128811e+11  7.003141e+09  +39.3349735  -111.6563633  2.557709e+06
# 8   2.486097e+11  6.189845e+09  +43.9715225  -120.6226269  3.282759e+06
# 9   1.721202e+11  1.254112e+10  +47.4162296  -120.5996231  2.928345e+06
# 10  1.980200e+08  1.306931e+09  -14.2638166  -170.6620902  3.224369e+05
# 11  2.140458e+11  2.397722e+09  +44.3020948  -114.5956254  4.186751e+06
# 12  4.722336e+08  4.644349e+09  +14.9367835  +145.6010210  9.595386e+05
# 13  8.867750e+09  4.923523e+09  +18.2176480  -066.4107992  8.396577e+05
# 14  1.776626e+11  3.374904e+09  +35.5900512  -097.4868150  3.308745e+06
# 15  1.904858e+10  3.542795e+09  +40.1072744  -074.6652012  1.095663e+06
# 16  2.677668e+09  1.323566e+09  +41.5974187  -071.5272723  4.768065e+05
# 17  1.118995e+11  2.375175e+10  +30.8577705  -091.8032730  3.079301e+06
# 18  1.254207e+10  1.815307e+09  +41.5797842  -072.7466665  7.069575e+05
# 19  3.478925e+08  1.550515e+09  +18.3267485  -064.9712501  2.958531e+05
# 20  6.226659e+10  4.894284e+08  +38.6472854  -080.6183274  2.614082e+06
# 21  1.058309e+11  1.026682e+10  +40.4149297  -082.7119975  2.127175e+06
# 22  1.022703e+11  2.385381e+09  +37.5336844  -085.2929801  2.753242e+06
# 23  1.489696e+11  4.941019e+09  +32.6293840  -083.4232125  2.534377e+06
# 24  1.215322e+11  3.928213e+09  +32.6864714  -089.6561377  2.856024e+06
# 25  2.020236e+10  7.133378e+09  +42.1565196  -071.4895915  1.478363e+06
# 26  5.047068e+09  1.398702e+09  +38.9976335  -075.4414957  5.421975e+05
# 27  2.387111e+10  1.035158e+09  +44.0605475  -072.6733540  1.285387e+06
# 28  1.158839e+11  3.396118e+09  +40.9024957  -077.8334514  2.174332e+06
# 29  2.514223e+10  6.988860e+09  +38.9466584  -076.6744939  1.836130e+06
# 30  1.068030e+11  2.350088e+09  +35.8585639  -086.3493573  2.620541e+06
# 31  1.311726e+11  4.594750e+09  +32.7396323  -086.8434593  2.125033e+06
# 32  1.022798e+11  8.506785e+09  +37.5222512  -078.6681938  2.951828e+06
# 33  1.780394e+11  2.500848e+09  +38.3507500  -092.4567826  3.050127e+06
# 34  2.318796e+10  1.026252e+09  +43.6726907  -071.5843145  1.355999e+06
# 35  7.988380e+10  1.175032e+10  +45.3906022  -068.6574869  2.553981e+06
# 36  7.785752e+10  5.075144e+09  +33.8741769  -080.8542699  1.856239e+06
# 37  1.446692e+11  1.076688e+09  +42.0700243  -093.4933473  2.527078e+06
# 38  1.259213e+11  1.346950e+10  +35.5397100  -079.1308636  2.668087e+06
# 39  2.117531e+11  1.346458e+09  +38.4985464  -098.3834298  2.571272e+06
# 40  1.989723e+11  1.356430e+09  +41.5438105  -099.8123253  2.921803e+06
# 41  2.514717e+11  1.862590e+09  +42.9918024  -107.5419255  2.777607e+06
# 42  2.684329e+11  1.170526e+09  +38.9938777  -105.5083161  2.708407e+06
# 43  2.062365e+11  1.892491e+10  +46.3161343  -094.1994801  4.512477e+06
# 44  1.402689e+11  2.936599e+10  +44.6284840  -089.7119299  3.029804e+06
# 45  1.464453e+11  1.040415e+11  +44.8410835  -085.6593197  3.795823e+06
# 46  9.278938e+10  1.536839e+09  +39.9030256  -086.2839503  2.212352e+06
# 47  1.478466e+12  2.448704e+11  +63.3461910  -152.8370679  3.603583e+07
# 48  6.765937e+11  1.906789e+10  +31.4347032  -099.2818238  6.845873e+06
# 49  1.389042e+11  3.140739e+10  +28.4574302  -082.4091478  3.734782e+06
# 50  1.581147e+08  1.888501e+07  +38.9041031  -077.0172290  8.623523e+04
# 51  1.437946e+11  6.200736e+09  +40.1028754  -089.1526108  2.860874e+06
# 52  5.433893e+08  9.345200e+08  +13.4383000  +144.7729285  1.792113e+05
# 53  2.942067e+11  1.026189e+09  +34.2039240  -111.6064072  2.908701e+06
# 54  2.843324e+11  2.047792e+09  +39.3310928  -116.6151469  3.056366e+06
# 55  4.034672e+11  2.049980e+10  +37.1551773  -119.5434183  5.258041e+06
#
#       Shape_Area                                           geometry
# 0   3.268482e+10  MULTIPOLYGON (((-17361760.204 2164544.588, -17...
# 1   2.053261e+11  POLYGON ((-10515267.713 4101325.818, -10515269...
# 2   4.643927e+11  POLYGON ((-12138963.727 4106855.170, -12138964...
# 3   8.201836e+11  POLYGON ((-12727480.235 5886876.586, -12727567...
# 4   2.637702e+11  MULTIPOLYGON (((-8866092.533 5160809.769, -886...
# 5   4.003467e+11  POLYGON ((-11582613.606 6227717.739, -11582612...
# 6   3.919805e+11  POLYGON ((-11583304.027 5487755.962, -11583301...
# 7   3.682852e+11  POLYGON ((-12576795.155 5160745.479, -12576496...
# 8   4.919336e+11  POLYGON ((-13625641.088 5711873.575, -13625180...
# 9   4.032186e+11  POLYGON ((-13029028.568 6063029.797, -13029028...
# 10  1.608089e+09  MULTIPOLYGON (((-19002932.440 -1597756.372, -1...
# 11  4.246766e+11  POLYGON ((-13013010.165 5489080.377, -13012923...
# 12  5.622529e+09  MULTIPOLYGON (((16238839.699 1704814.574, 1623...
# 13  1.536790e+10  MULTIPOLYGON (((-7360957.723 2098864.562, -736...
# 14  2.744190e+11  POLYGON ((-10924792.407 4047868.443, -10924904...
# 15  3.867491e+10  POLYGON ((-8356399.819 4944221.685, -8356398.5...
# 16  7.160113e+09  MULTIPOLYGON (((-7939057.912 5127502.310, -793...
# 17  1.849588e+11  POLYGON ((-10195960.329 3421467.089, -10196226...
# 18  2.567750e+10  POLYGON ((-8182865.488 5129802.992, -8182858.6...
# 19  2.111588e+09  MULTIPOLYGON (((-7218370.769 2083684.186, -721...
# 20  1.030460e+11  POLYGON ((-9021809.270 4798831.851, -9021755.7...
# 21  2.005836e+11  POLYGON ((-9397981.315 4729107.457, -9398094.4...
# 22  1.667136e+11  MULTIPOLYGON (((-9628030.894 4585894.901, -962...
# 23  2.177931e+11  POLYGON ((-9365246.889 4162189.599, -9365223.8...
# 24  1.778441e+11  POLYGON ((-10200950.568 3632693.765, -10200867...
# 25  4.978583e+10  POLYGON ((-8174335.855 5205445.266, -8174143.9...
# 26  1.068685e+10  POLYGON ((-8433573.074 4764279.107, -8433576.0...
# 27  4.827778e+10  POLYGON ((-8171675.999 5468581.236, -8171694.8...
# 28  2.090146e+11  POLYGON ((-8938260.406 4825509.401, -8938275.2...
# 29  5.320418e+10  POLYGON ((-8576278.913 4685457.299, -8576266.3...
# 30  1.664798e+11  POLYGON ((-9945959.215 4370089.033, -9944979.2...
# 31  1.926309e+11  POLYGON ((-9841333.855 3579579.495, -9841349.6...
# 32  1.764158e+11  POLYGON ((-8603460.912 4628566.411, -8603229.4...
# 33  2.943634e+11  POLYGON ((-10532846.085 4398635.658, -10532846...
# 34  4.632278e+10  POLYGON ((-8051696.589 5403780.752, -8051573.4...
# 35  1.851447e+11  POLYGON ((-7910167.957 5620029.832, -7910173.9...
# 36  1.206545e+11  POLYGON ((-9210687.184 4056882.575, -9210705.6...
# 37  2.648102e+11  POLYGON ((-10312404.419 4952179.681, -10312552...
# 38  2.109441e+11  POLYGON ((-9023219.991 4175713.226, -9023205.5...
# 39  3.484442e+11  POLYGON ((-11115260.161 4866178.540, -11115124...
# 40  3.578647e+11  POLYGON ((-10675250.613 4866030.931, -10675713...
# 41  4.742128e+11  POLYGON ((-12312694.046 5011793.594, -12312702...
# 42  4.473071e+11  POLYGON ((-12139399.612 4944791.641, -12139399...
# 43  4.731766e+11  POLYGON ((-10737141.426 5469123.028, -10737144...
# 44  3.353652e+11  POLYGON ((-10316483.786 5682000.241, -10316376...
# 45  4.997449e+11  POLYGON ((-9694630.066 5196297.977, -9694217.2...
# 46  1.606530e+11  POLYGON ((-9743415.725 5036871.998, -9743415.6...
# 47  9.015681e+12  MULTIPOLYGON (((-15108567.654 8339788.089, -15...
# 48  9.607260e+11  POLYGON ((-11473106.144 3889876.760, -11473097...
# 49  2.215002e+11  MULTIPOLYGON (((-9734892.689 3569910.909, -973...
# 50  2.926993e+08  POLYGON ((-8584931.670 4712273.246, -8584832.5...
# 51  2.570903e+11  POLYGON ((-10098457.077 4749135.984, -10098459...
# 52  1.571727e+09  POLYGON ((16142071.912 1526177.190, 16141988.6...
# 53  4.340760e+11  POLYGON ((-12761162.105 4147165.875, -12761214...
# 54  4.803030e+11  POLYGON ((-13320110.880 4687700.218, -13320611...
# 55  6.718927e+11  MULTIPOLYGON (((-13060108.516 3854208.959, -13...

# %%
states = states.loc[states["STUSPS"].isin(df["state"].unique())]

# %%
states.plot(figsize=(40, 40))
# Out:
# <AxesSubplot:>

# %%
df["state"].unique()
# Out:
# 51
